# %%
import yfinance as yf

# %%
btc = yf.Ticker("BTC-USD")

# %%
print(btc)
# Out:
# yfinance.Ticker object <BTC-USD>

# %%
btc.info
# Out:
# {'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,780,268. The last known price of Bitcoin is 79,482.63227078 USD and is up 3.78 over the last 24 hours. It is currently trading on 11797 active market(s) with $48,397,882,908.02 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 80444.125,
#  'open': 80444.125,
#  'dayLow': 80444.125,
#  'dayHigh': 80772.164,
#  'regularMarketPreviousClose': 80444.125,
#  'regularMarketOpen': 80444.125,
#  'regularMarketDayLow': 80444.125,
#  'regularMarketDayHigh': 80772.164,
#  'volume': 82735874048,
#  'regularMarketVolume': 82735874048,
#  'averageVolume': 32203621221,
#  'averageVolume10days': 49714898305,
#  'averageDailyVolume10Day': 49714898305,
#  'marketCap': 1591431004160,
# ...

# %%
btc.history(period="max")
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-11-06 00:00:00+00:00  69358.500000  76460.156250  69322.031250
# 2024-11-07 00:00:00+00:00  75637.085938  76943.117188  74480.421875
# 2024-11-08 00:00:00+00:00  75902.835938  77252.750000  75648.742188
# 2024-11-09 00:00:00+00:00  76556.187500  76932.765625  75773.789062
# 2024-11-11 00:00:00+00:00  80444.125000  80772.164062  80444.125000
#
#                                   Close        Volume  Dividends  Stock Splits
# Date
# ...

# %%
eth = yf.Ticker("ETH-USD")

# %%
eth.info
# Out:
# {'twitter': '"https://twitter.com/ethereum"',
#  'name': 'Ethereum',
#  'startDate': 1438905600,
#  'description': 'Ethereum (ETH) is a cryptocurrency . Ethereum has a current supply of 120,423,059.36814076. The last known price of Ethereum is 3,190.21762975 USD and is up 4.78 over the last 24 hours. It is currently trading on 9506 active market(s) with $33,143,802,871.71 traded over the last 24 hours. More information can be found at https://www.ethereum.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 3187.5813,
#  'open': 3187.5813,
#  'dayLow': 3186.2583,
#  'dayHigh': 3200.409,
#  'regularMarketPreviousClose': 3187.5813,
#  'regularMarketOpen': 3187.5813,
#  'regularMarketDayLow': 3186.2583,
#  'regularMarketDayHigh': 3200.409,
#  'volume': 47517958144,
#  'regularMarketVolume': 47517958144,
#  'averageVolume': 15876569846,
#  'averageVolume10days': 23904063015,
#  'averageDailyVolume10Day': 23904063015,
#  'marketCap': 384194707456,
# ...

# %%
eth.history(period="max")
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2017-11-09 00:00:00+00:00   308.644989   329.451996   307.056000   320.884003
# 2017-11-10 00:00:00+00:00   320.670990   324.717987   294.541992   299.252991
# 2017-11-11 00:00:00+00:00   298.585999   319.453003   298.191986   314.681000
# 2017-11-12 00:00:00+00:00   314.690002   319.153015   298.513000   307.907990
# 2017-11-13 00:00:00+00:00   307.024994   328.415009   307.024994   316.716003
# ...                                ...          ...          ...          ...
# 2024-11-06 00:00:00+00:00  2422.539307  2743.964111  2421.812988  2724.169189
# 2024-11-07 00:00:00+00:00  2724.005859  2918.744385  2701.590820  2895.585449
# 2024-11-08 00:00:00+00:00  2895.597900  2983.744873  2889.484375  2962.296631
# 2024-11-09 00:00:00+00:00  2962.791016  3156.366211  2957.182373  3131.144531
# 2024-11-11 00:00:00+00:00  3187.581299  3200.408936  3186.258301  3192.855469
#
# ...
